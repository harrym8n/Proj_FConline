# %%
import requests
headers = {
  "x-nxopen-api-key": "test_7cd2e08122133d0d9ea57e25d2e9b09b39d14070fa9398f77b6799dfa6924a57efe8d04e6d233bd35cf2fabdeb93fb0d"
}
  
characterName = "Ithas"
urlString = "https://open.api.nexon.com/heroes/v1/id?character_name=" + characterName
response = requests.get(urlString, headers = headers)
  
print(response.json())
# Out:
# {'error': {'name': 'OPENAPI00006', 'message': 'The api path is not valid.'}}
